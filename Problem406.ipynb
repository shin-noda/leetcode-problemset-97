# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-problemset-97/blob/main/Problem406.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Solution:
    def reconstructQueue(self, people):
        # First, sort by the first element in decreasing order and then,
        # sort it by the 2nd order.
        people.sort(key=lambda x: (-x[0], x[1]))
        result = []

        for person in people:
            result.insert(person[1], person)

        return result

# %%
solution = Solution()

# %%
people = [[7,0],[4,4],[7,1],[5,0],[6,1],[5,2]]

print(solution.reconstructQueue(people))
# Out:
# [[5, 0], [7, 0], [5, 2], [6, 1], [4, 4], [7, 1]]

# %%
people = [[6,0],[5,0],[4,0],[3,2],[2,2],[1,4]]

print(solution.reconstructQueue(people))
# Out:
# [[4, 0], [5, 0], [2, 2], [3, 2], [1, 4], [6, 0]]
