# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-problemset-97/blob/main/Problem192.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""

tr -s '[:space:]' '\n' < words.txt | sort | uniq -c | sort -nr | awk '{print $2, $1}'

"""
# Out:
# "\n\ntr ' ' '\n' < words.txt | sort | uniq -c | sort -nr\n\n"

# %%
# Read from the file words.txt and output the word frequency list to stdout.
