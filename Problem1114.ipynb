# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-problemset-97/blob/main/Problem1114.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import threading

class Foo:
    def __init__(self):
        self.first_done = threading.Event()
        self.second_done = threading.Event()


    def first(self, printFirst):
        # printFirst() outputs "first". Do not change or remove this line.
        printFirst()

        # Unlock the second()
        self.first_done.set()


    def second(self, printSecond):
        # Wait until first() is done. If it's already done, it'll be ignored.
        self.first_done.wait()

        # printSecond() outputs "second". Do not change or remove this line.
        printSecond()

        # Unlock the third()
        self.second_done.set()


    def third(self, printThird):
        # Wait until second() is done. If it's already done, it'll be ignored.
        self.second_done.wait()

        # printThird() outputs "third". Do not change or remove this line.
        printThird()
