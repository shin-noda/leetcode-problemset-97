# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-problemset-97/blob/main/Problem802.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Solution:
    def eventualSafeNodes(self, graph):
        # A terminal node: No outgoing edges
        # A safe node: Every possible path starting from that node leads to a terminal node

        results = []
        terminal_nodes = set()
        safe_nodes = set()
        dir = {}
        rev = {}

        for i in range(len(graph)):
            if len(graph[i]) == 0:
                terminal_nodes.add(i)
                safe_nodes.add(i)

            else:
                dir[i] = set()
                for j in range(len(graph[i])):
                    dir[i].add(graph[i][j])

                    if graph[i][j] not in rev:
                        rev[graph[i][j]] = set()

                    rev[graph[i][j]].add(i)

        while terminal_nodes:
            node = terminal_nodes.pop()

            if node not in rev:
                continue

            nodes = rev[node]

            # Delete the key
            rev.pop(node, None)

            for curr in nodes:
                if curr in dir:
                    dir[curr].discard(node)

                    if len(dir[curr]) == 0:
                        safe_nodes.add(curr)
                        terminal_nodes.add(curr)

                        # Delete the key
                        dir.pop(curr, None)

        results = list(safe_nodes)
        results.sort()

        return results

# %%
solution = Solution()

# %%
graph = [[1,2],[2,3],[5],[0],[5],[],[]]

print(solution.eventualSafeNodes(graph))
# Out:
# [2, 4, 5, 6]

# %%
graph = [[1,2,3,4],[1,2],[3,4],[0,4],[]]

print(solution.eventualSafeNodes(graph))
# Out:
# [4]

# %%
graph = [[],[0,2,3,4],[3],[4],[]]

# Expected: [0,1,2,3,4]
print(solution.eventualSafeNodes(graph))
# Out:
# [0, 1, 2, 3, 4]
